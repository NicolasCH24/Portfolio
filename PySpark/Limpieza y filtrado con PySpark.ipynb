# %%
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
from pyspark.sql import Row

# %%
from pyspark.sql.functions import when

# %%
spark = SparkSession.builder \
    .appName("CrearDataFrame") \
    .master("local") \
    .getOrCreate()

# %%
df = spark.read.csv("C:/Dropbox/CursoSpark/spotify.csv", header=True, sep=",")

# %%
df.show()
# Out:
# +---+--------------------+--------------------+--------------------+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# |_c0|            track_id|             artists|          album_name|          track_name|popularity|duration_ms|explicit|danceability|energy|key|loudness|mode|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|time_signature|track_genre|
# +---+--------------------+--------------------+--------------------+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# |  0|5SuOikwiRyPMVoIQD...|         Gen Hoshino|              Comedy|              Comedy|        73|     230666|   False|       0.676| 0.461|  1|  -6.746|   0|      0.143|      0.0322|        1.01e-06|   0.358|  0.715| 87.917|             4|   acoustic|
# |  1|4qPNDBW1i3p13qLCt...|        Ben Woodward|    Ghost (Acoustic)|    Ghost - Acoustic|        55|     149610|   False|        0.42| 0.166|  1| -17.235|   1|     0.0763|       0.924|        5.56e-06|   0.101|  0.267| 77.489|             4|   acoustic|
# |  2|1iJBSr7s7jYXzM8EG...|Ingrid Michaelson...|      To Begin Again|      To Begin Again|        57|     210826|   False|       0.438| 0.359|  0|  -9.734|   1|     0.0557|        0.21|             0.0|   0.117|   0.12| 76.332|             4|   acoustic|
# |  3|6lfxq3CG4xtTiEg7o...|        Kina Grannis|Crazy Rich Asians...|Can't Help Fallin...|        71|     201933|   False|       0.266|0.0596|  0| -18.515|   1|     0.0363|       0.905|        7.07e-05|   0.132|  0.143| 181.74|             3|   acoustic|
# |  4|5vjLSffimiIP26QG5...|    Chord Overstreet|             Hold On|             Hold On|        82|     198853|   False|       0.618| 0.443|  2|  -9.681|   1|     0.0526|       0.469|             0.0|  0.0829|  0.167|119.949|             4|   acoustic|
# |  5|01MVOl9KtVTNfFiBU...|        Tyrone Wells|Days I Will Remember|Days I Will Remember|        58|     214240|   False|       0.688| 0.481|  6|  -8.807|   1|      0.105|       0.289|             0.0|   0.189|  0.666| 98.017|             4|   acoustic|
# |  6|6Vc5wAMmXdKIAM7WU...|A Great Big World...|Is There Anybody ...|       Say Something|        74|     229400|   False|       0.407| 0.147|  2|  -8.822|   1|     0.0355|       0.857|        2.89e-06|  0.0913| 0.0765|141.284|             3|   acoustic|
# |  7|1EzrEOXmMH3G43AXT...|          Jason Mraz|We Sing. We Dance...|           I'm Yours|        80|     242946|   False|       0.703| 0.444| 11|  -9.331|   1|     0.0417|       0.559|             0.0|  0.0973|  0.712| 150.96|             4|   acoustic|
# |  8|0IktbUcnAGrvD03AW...|Jason Mraz;Colbie...|We Sing. We Dance...|               Lucky|        74|     189613|   False|       0.625| 0.414|  0|    -8.7|   1|     0.0369|       0.294|             0.0|   0.151|  0.669|130.088|             4|   acoustic|
# |  9|7k9GuJYLp2AzqokyE...|      Ross Copperman|              Hunger|              Hunger|        56|     205594|   False|       0.442| 0.632|  1|   -6.77|   1|     0.0295|       0.426|         0.00419|  0.0735|  0.196| 78.899|             4|   acoustic|
# | 10|4mzP5mHkRvGxdhdGd...|        Zack Tabudlo|             Episode|Give Me Your Forever|        74|     244800|   False|       0.627| 0.363|  8|  -8.127|   1|     0.0291|       0.279|             0.0|  0.0928|  0.301| 99.905|             4|   acoustic|
# | 11|5ivF4eQBqJiVL5IAE...|          Jason Mraz|Love Is a Four Le...|     I Won't Give Up|        69|     240165|   False|       0.483| 0.303|  4| -10.058|   1|     0.0429|       0.694|             0.0|   0.115|  0.139|133.406|             3|   acoustic|
# | 12|4ptDJbJl35d7gQfeN...|            Dan Berk|                Solo|                Solo|        52|     198712|   False|       0.489| 0.314|  7|  -9.245|   0|     0.0331|       0.749|             0.0|   0.113|  0.607|124.234|             4|   acoustic|
# | 13|0X9MxHR1rTkEHDjp9...|       Anna Hamilton|            Bad Liar|            Bad Liar|        62|     248448|   False|       0.691| 0.234|  3|  -6.441|   1|     0.0285|       0.777|             0.0|    0.12|  0.209| 87.103|             4|   acoustic|
# | 14|4LbWtBkN82ZRhz9jq...|Chord Overstreet;...|     Hold On (Remix)|     Hold On - Remix|        56|     188133|   False|       0.755|  0.78|  2|  -6.084|   1|     0.0327|       0.124|        2.83e-05|   0.121|  0.387|120.004|             4|   acoustic|
# | 15|1KHdq8NK9QxnGjdXb...|         Landon Pigg|   The Boy Who Never|Falling in Love a...|        58|     244986|   False|       0.489| 0.561|  4|  -7.933|   1|     0.0274|         0.2|        4.56e-05|   0.179|  0.238| 83.457|             3|   acoustic|
# | 16|6xKeQgzfjixSUld14...|Andrew Foy;Renee Foy|ily (i love you b...|ily (i love you b...|        56|     129750|   False|       0.706| 0.112|  2| -18.098|   1|     0.0391|       0.827|        4.03e-06|   0.125|  0.414|110.154|             4|   acoustic|
# | 17|4Yo0igmcoNyat1sec...|Andrew Foy;Renee Foy|         At My Worst|         At My Worst|        54|     169728|   False|       0.795|0.0841| 10|  -18.09|   0|     0.0461|       0.742|        1.17e-05|  0.0853|  0.609| 91.803|             4|   acoustic|
# | 18|2qLMf6TuEC3ruGJg4...|Jason Mraz;Colbie...|We Sing. We Dance...|               Lucky|        68|     189613|   False|       0.625| 0.414|  0|    -8.7|   1|     0.0369|       0.294|             0.0|   0.151|  0.669|130.088|             4|   acoustic|
# | 19|6CgNoAbFJ4Q4Id4Ej...|Boyce Avenue;Bea ...|Cover Sessions, V...|          Photograph|        67|     260186|   False|       0.717|  0.32|  3|  -8.393|   1|     0.0283|        0.83|             0.0|   0.107|  0.322|107.946|             4|   acoustic|
# +---+--------------------+--------------------+--------------------+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# only showing top 20 rows

# %%
df = df.na.drop()

# %%
df.columns
# Out:
# ['_c0',
#  'track_id',
#  'artists',
#  'album_name',
#  'track_name',
#  'popularity',
#  'duration_ms',
#  'explicit',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'time_signature',
#  'track_genre']

# %%
df = df.dropDuplicates()

# %%
num_filas = df.count()
num_columnas = len(df.columns)
print("Numero de filas:", num_filas)
print("Numero de columnas:", num_columnas)
# Out:
# Numero de filas: 113999
# Numero de columnas: 21

# %%
df = df.drop('track_id')

# %%
df.show(3)
# Out:
# +----+-------------+--------------------+----------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# | _c0|      artists|          album_name|      track_name|popularity|duration_ms|explicit|danceability|energy|key|loudness|mode|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|time_signature|track_genre|
# +----+-------------+--------------------+----------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# | 539| Boyce Avenue|Cover Sessions, V...|Someone Like You|        57|     276146|   False|       0.439| 0.207|  1|  -9.573|   1|     0.0297|       0.608|             0.0|   0.186|  0.264|136.514|             4|   acoustic|
# | 831|Little Walter|The Essential Lit...|         My Babe|        59|     162040|   False|       0.676| 0.334|  5| -10.572|   1|     0.0508|       0.862|             0.0|    0.32|  0.867|  158.0|             4|   acoustic|
# |1087|Hugh Masekela| Africa Rising Vol.3|          Makoti|         0|     274933|   False|       0.469| 0.824|  8| -10.785|   1|     0.0944|       0.478|           0.268|   0.076|  0.781|220.081|             4|   afrobeat|
# +----+-------------+--------------------+----------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# only showing top 3 rows

# %%
df = df.withColumn('explicit', when(df.explicit == True, 1).otherwise(0))

# %%
df.show()
# Out:
# +----+--------------------+--------------------+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# | _c0|             artists|          album_name|          track_name|popularity|duration_ms|explicit|danceability|energy|key|loudness|mode|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|time_signature|track_genre|
# +----+--------------------+--------------------+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# | 539|        Boyce Avenue|Cover Sessions, V...|    Someone Like You|        57|     276146|       0|       0.439| 0.207|  1|  -9.573|   1|     0.0297|       0.608|             0.0|   0.186|  0.264|136.514|             4|   acoustic|
# | 831|       Little Walter|The Essential Lit...|             My Babe|        59|     162040|       0|       0.676| 0.334|  5| -10.572|   1|     0.0508|       0.862|             0.0|    0.32|  0.867|  158.0|             4|   acoustic|
# |1087|       Hugh Masekela| Africa Rising Vol.3|              Makoti|         0|     274933|       0|       0.469| 0.824|  8| -10.785|   1|     0.0944|       0.478|           0.268|   0.076|  0.781|220.081|             4|   afrobeat|
# |1090|      Criolo;Emicida|Criolo E Emicida ...|      Triunfo - Live|        34|     273426|       0|        0.54| 0.945|  1|  -5.021|   1|      0.271|       0.315|             0.0|   0.405|  0.551| 92.013|             4|   afrobeat|
# |1096|       Jackie Mittoo|The Keyboard King...|         Black Organ|        34|     191506|       0|       0.837| 0.598|  1|  -9.047|   0|      0.181|       0.391|           0.238|  0.0598|  0.983|145.219|             4|   afrobeat|
# |1109|            Calle 13|Los De Atrás Vien...|Bienvenidos A Mi ...|        33|     237026|       1|       0.658| 0.715| 10|  -7.416|   0|      0.269|      0.0174|             0.0|   0.307|  0.543|189.895|             4|   afrobeat|
# |1283|    Samuca e a Selva|             Feitiço|             Feitiço|        24|     262425|       0|       0.869| 0.797|  6|  -4.455|   1|     0.0318|       0.414|             0.0|  0.0852|  0.973|121.996|             4|   afrobeat|
# |1793|            Calle 13|Los De Atrás Vien...|  Electro Movimiento|        19|     196986|       0|       0.803|  0.86|  8|  -6.522|   1|      0.135|      0.0782|        4.45e-05|   0.128|  0.534|109.966|             4|   afrobeat|
# |1974|        Manu Dibango|           Home Made|     Tropical Garden|        16|     502693|       0|       0.615| 0.397|  0| -17.526|   0|     0.0859|       0.301|           0.886|  0.0277|  0.916|  169.0|             4|   afrobeat|
# |2260|Red Hot Chili Pep...|By the Way (Delux...|          Can't Stop|        82|     269000|       0|       0.618| 0.938|  9|  -3.442|   1|     0.0456|      0.0179|             0.0|   0.167|  0.875| 91.455|             4|   alt-rock|
# |2363|            The 1975|Being Funny In A ...|Looking For Someb...|        72|     178617|       1|       0.522| 0.957|  2|  -4.924|   1|     0.0687|      0.0515|          0.0014|   0.144|  0.917| 170.91|             4|   alt-rock|
# |2514|            Weathers|         Happy Pills|         Happy Pills|        71|     203080|       0|       0.521| 0.885|  4|  -4.934|   0|      0.125|     0.00327|         0.00904|   0.324|  0.344|115.985|             4|   alt-rock|
# |2638|          Callejeros|             Presión|             Presión|        47|     238346|       0|       0.414| 0.938| 10|  -4.592|   0|     0.0684|      0.0602|        1.18e-06|    0.11|  0.643| 99.014|             4|   alt-rock|
# |2783|Siouxsie and the ...|Halloween Scary P...|           Halloween|         0|     221466|       0|       0.223|  0.91|  7|  -7.097|   1|       0.08|      0.0116|        0.000518|   0.212|  0.364| 171.75|             4|   alt-rock|
# |2989|               La 25|Entre Cuervos y C...|       De Paso Nomás|        44|     185501|       0|       0.646| 0.846|  7|  -4.427|   1|     0.0282|      0.0584|             0.0|   0.376|  0.965|126.022|             4|   alt-rock|
# |3050|                MGMT|     Little Dark Age|     Little Dark Age|        83|     299960|       0|       0.705| 0.712|  6|  -6.156|   1|     0.0385|      0.0102|        0.000855|     0.1|   0.62| 97.512|             4|alternative|
# |3307|      Princess Nokia|    Everything Sucks|          I Like Him|        66|     132453|       1|       0.893| 0.579|  9|  -8.995|   1|      0.113|      0.0641|        0.000121|   0.215|  0.611|133.018|             4|alternative|
# |3723|             Nirvana|Nevermind (Remast...|             Lithium|        73|     257053|       0|       0.678| 0.656|  7|   -6.41|   1|     0.0381|     0.00174|             0.0|  0.0631|  0.485|123.207|             4|alternative|
# |4817|        Simon Wester|Echoes in the Val...|     The Narrow Path|        39|     226857|       0|       0.167|0.0709|  5| -25.474|   1|     0.0341|       0.967|           0.958|   0.107| 0.0391|111.917|             4|    ambient|
# |4925|      Alexis Ffrench|Walk With Us (For...|Walk With Us - Fo...|        57|     120456|       0|       0.299|0.0264|  9| -26.535|   0|     0.0469|       0.995|           0.882|   0.073|  0.235|168.963|             5|    ambient|
# +----+--------------------+--------------------+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col

# Supongamos que 'columna' es el nombre de la columna que deseas convertir
nombre_columna = 'popularity'

# Convertir la columna a tipo entero y filtrar las filas inválidas
df = df.withColumn(nombre_columna, col(nombre_columna).cast('int')) \
       .filter(col(nombre_columna).isNotNull())

# Mostrar el DataFrame resultante
df.show()
# Out:
# +----+--------------------+--------------------+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# | _c0|             artists|          album_name|          track_name|popularity|duration_ms|explicit|danceability|energy|key|loudness|mode|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|time_signature|track_genre|
# +----+--------------------+--------------------+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# | 539|        Boyce Avenue|Cover Sessions, V...|    Someone Like You|        57|     276146|       0|       0.439| 0.207|  1|  -9.573|   1|     0.0297|       0.608|             0.0|   0.186|  0.264|136.514|             4|   acoustic|
# | 831|       Little Walter|The Essential Lit...|             My Babe|        59|     162040|       0|       0.676| 0.334|  5| -10.572|   1|     0.0508|       0.862|             0.0|    0.32|  0.867|  158.0|             4|   acoustic|
# |1087|       Hugh Masekela| Africa Rising Vol.3|              Makoti|         0|     274933|       0|       0.469| 0.824|  8| -10.785|   1|     0.0944|       0.478|           0.268|   0.076|  0.781|220.081|             4|   afrobeat|
# |1090|      Criolo;Emicida|Criolo E Emicida ...|      Triunfo - Live|        34|     273426|       0|        0.54| 0.945|  1|  -5.021|   1|      0.271|       0.315|             0.0|   0.405|  0.551| 92.013|             4|   afrobeat|
# |1096|       Jackie Mittoo|The Keyboard King...|         Black Organ|        34|     191506|       0|       0.837| 0.598|  1|  -9.047|   0|      0.181|       0.391|           0.238|  0.0598|  0.983|145.219|             4|   afrobeat|
# |1109|            Calle 13|Los De Atrás Vien...|Bienvenidos A Mi ...|        33|     237026|       1|       0.658| 0.715| 10|  -7.416|   0|      0.269|      0.0174|             0.0|   0.307|  0.543|189.895|             4|   afrobeat|
# |1283|    Samuca e a Selva|             Feitiço|             Feitiço|        24|     262425|       0|       0.869| 0.797|  6|  -4.455|   1|     0.0318|       0.414|             0.0|  0.0852|  0.973|121.996|             4|   afrobeat|
# |1793|            Calle 13|Los De Atrás Vien...|  Electro Movimiento|        19|     196986|       0|       0.803|  0.86|  8|  -6.522|   1|      0.135|      0.0782|        4.45e-05|   0.128|  0.534|109.966|             4|   afrobeat|
# |1974|        Manu Dibango|           Home Made|     Tropical Garden|        16|     502693|       0|       0.615| 0.397|  0| -17.526|   0|     0.0859|       0.301|           0.886|  0.0277|  0.916|  169.0|             4|   afrobeat|
# |2260|Red Hot Chili Pep...|By the Way (Delux...|          Can't Stop|        82|     269000|       0|       0.618| 0.938|  9|  -3.442|   1|     0.0456|      0.0179|             0.0|   0.167|  0.875| 91.455|             4|   alt-rock|
# |2363|            The 1975|Being Funny In A ...|Looking For Someb...|        72|     178617|       1|       0.522| 0.957|  2|  -4.924|   1|     0.0687|      0.0515|          0.0014|   0.144|  0.917| 170.91|             4|   alt-rock|
# |2514|            Weathers|         Happy Pills|         Happy Pills|        71|     203080|       0|       0.521| 0.885|  4|  -4.934|   0|      0.125|     0.00327|         0.00904|   0.324|  0.344|115.985|             4|   alt-rock|
# |2638|          Callejeros|             Presión|             Presión|        47|     238346|       0|       0.414| 0.938| 10|  -4.592|   0|     0.0684|      0.0602|        1.18e-06|    0.11|  0.643| 99.014|             4|   alt-rock|
# |2783|Siouxsie and the ...|Halloween Scary P...|           Halloween|         0|     221466|       0|       0.223|  0.91|  7|  -7.097|   1|       0.08|      0.0116|        0.000518|   0.212|  0.364| 171.75|             4|   alt-rock|
# |2989|               La 25|Entre Cuervos y C...|       De Paso Nomás|        44|     185501|       0|       0.646| 0.846|  7|  -4.427|   1|     0.0282|      0.0584|             0.0|   0.376|  0.965|126.022|             4|   alt-rock|
# |3050|                MGMT|     Little Dark Age|     Little Dark Age|        83|     299960|       0|       0.705| 0.712|  6|  -6.156|   1|     0.0385|      0.0102|        0.000855|     0.1|   0.62| 97.512|             4|alternative|
# |3307|      Princess Nokia|    Everything Sucks|          I Like Him|        66|     132453|       1|       0.893| 0.579|  9|  -8.995|   1|      0.113|      0.0641|        0.000121|   0.215|  0.611|133.018|             4|alternative|
# |3723|             Nirvana|Nevermind (Remast...|             Lithium|        73|     257053|       0|       0.678| 0.656|  7|   -6.41|   1|     0.0381|     0.00174|             0.0|  0.0631|  0.485|123.207|             4|alternative|
# |4817|        Simon Wester|Echoes in the Val...|     The Narrow Path|        39|     226857|       0|       0.167|0.0709|  5| -25.474|   1|     0.0341|       0.967|           0.958|   0.107| 0.0391|111.917|             4|    ambient|
# |4925|      Alexis Ffrench|Walk With Us (For...|Walk With Us - Fo...|        57|     120456|       0|       0.299|0.0264|  9| -26.535|   0|     0.0469|       0.995|           0.882|   0.073|  0.235|168.963|             5|    ambient|
# +----+--------------------+--------------------+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# only showing top 20 rows

# %%
num_filas = df.count()
num_columnas = len(df.columns)
print("Numero de filas:", num_filas)
print("Numero de columnas:", num_columnas)
# Out:
# Numero de filas: 113865
# Numero de columnas: 20

# %%
df.select('track_genre').distinct().show(n= df.count(), truncate= False)
# Out:
# +-----------------+
# |track_genre      |
# +-----------------+
# |anime            |
# |singer-songwriter|
# |folk             |
# |hardstyle        |
# |pop              |
# |alternative      |
# |death-metal      |
# |detroit-techno   |
# |idm              |
# |k-pop            |
# |j-dance          |
# |ambient          |
# |guitar           |
# |goth             |
# |cantopop         |
# |blues            |
# |study            |
# |malay            |
# |breakbeat        |
# |dance            |
# |groove           |
# |indian           |
# |german           |
# |sad              |
# |spanish          |
# |french           |
# |electronic       |
# |brazil           |
# |dub              |
# |deep-house       |
# |edm              |
# |rock-n-roll      |
# |power-pop        |
# |progressive-house|
# |swedish          |
# |synth-pop        |
# |chill            |
# |bluegrass        |
# |j-rock           |
# |party            |
# |hip-hop          |
# |reggaeton        |
# |techno           |
# |grunge           |
# |hard-rock        |
# |indie-pop        |
# |jazz             |
# |new-age          |
# |show-tunes       |
# |trip-hop         |
# |punk-rock        |
# |country          |
# |hardcore         |
# |industrial       |
# |british          |
# |metalcore        |
# |songwriter       |
# |j-idol           |
# |honky-tonk       |
# |kids             |
# |metal            |
# |soul             |
# |turkish          |
# |mpb              |
# |psych-rock       |
# |grindcore        |
# |pop-film         |
# |salsa            |
# |happy            |
# |mandopop         |
# |dancehall        |
# |r-n-b            |
# |club             |
# |indie            |
# |electro          |
# |latino           |
# |samba            |
# |drum-and-bass    |
# |heavy-metal      |
# |house            |
# |pagode           |
# |chicago-house    |
# |funk             |
# |alt-rock         |
# |disney           |
# |children         |
# |sleep            |
# |dubstep          |
# |gospel           |
# |world-music      |
# |acoustic         |
# |rockabilly       |
# |rock             |
# |ska              |
# |opera            |
# |black-metal      |
# |iranian          |
# |romance          |
# |emo              |
# |reggae           |
# |j-pop            |
# |tango            |
# |punk             |
# |disco            |
# |classical        |
# |latin            |
# |sertanejo        |
# |afrobeat         |
# |garage           |
# |forro            |
# |trance           |
# |minimal-techno   |
# |comedy           |
# |piano            |
# +-----------------+

# %%
genero_numero = {
    "anime": 0,
    "singer-songwriter": 1,
    "folk": 2,
    "hardstyle": 3,
    "pop": 4,
    "alternative": 5,
    "death-metal": 6,
    "detroit-techno": 7,
    "idm": 8,
    "k-pop": 9,
    "j-dance": 10,
    "ambient": 11,
    "guitar": 12,
    "goth": 13,
    "cantopop": 14,
    "blues": 15,
    "study": 16,
    "malay": 17,
    "breakbeat": 18,
    "dance": 19,
    "groove": 20,
    "indian": 21,
    "german": 22,
    "sad": 23,
    "spanish": 24,
    "french": 25,
    "electronic": 26,
    "brazil": 27,
    "dub": 28,
    "deep-house": 29,
    "edm": 30,
    "rock-n-roll": 31,
    "power-pop": 32,
    "progressive-house": 33,
    "swedish": 34,
    "synth-pop": 35,
    "chill": 36,
    "bluegrass": 37,
    "j-rock": 38,
    "party": 39,
    "hip-hop": 40,
    "reggaeton": 41,
    "techno": 42,
    "grunge": 43,
    "hard-rock": 44,
    "indie-pop": 45,
    "jazz": 46,
    "new-age": 47,
    "show-tunes": 48,
    "trip-hop": 49,
    "punk-rock": 50,
    "country": 51,
    "hardcore": 52,
    "industrial": 53,
    "british": 54,
    "metalcore": 55,
    "songwriter": 56,
    "j-idol": 57,
    "honky-tonk": 58,
    "kids": 59,
    "metal": 60,
    "soul": 61,
    "turkish": 62,
    "mpb": 63,
    "psych-rock": 64,
    "grindcore": 65,
    "pop-film": 66,
    "salsa": 67,
    "happy": 68,
    "mandopop": 69,
    "dancehall": 70,
    "r-n-b": 71,
    "club": 72,
    "indie": 73,
    "electro": 74,
    "latino": 75,
    "samba": 76,
    "drum-and-bass": 77,
    "heavy-metal": 78,
    "house": 79,
    "pagode": 80,
    "chicago-house": 81,
    "funk": 82,
    "alt-rock": 83,
    "disney": 84,
    "children": 85,
    "sleep": 86,
    "dubstep": 87,
    "gospel": 88,
    "world-music": 89,
    "acoustic": 90,
    "rockabilly": 91,
    "rock": 92,
    "ska": 93,
    "opera": 94,
    "black-metal": 95,
    "iranian": 96,
    "romance": 97,
    "emo": 98,
    "reggae": 99,
    "j-pop": 100,
    "tango": 101,
    "punk": 102,
    "disco": 103,
    "classical": 104,
    "latin": 105,
    "sertanejo": 106,
    "afrobeat": 107,
    "garage": 108,
    "forro": 109,
    "trance": 110,
    "minimal-techno": 111,
    "comedy": 112,
    "piano": 113
}

# %%
genero_claves = genero_numero.keys()

# %%
df.columns
# Out:
# ['_c0',
#  'artists',
#  'album_name',
#  'track_name',
#  'popularity',
#  'duration_ms',
#  'explicit',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'time_signature',
#  'track_genre']

# %%
df = df.drop('artists', 'albun_name')

# %%
df = df.drop('album_name')

# %%
filas = df.select('_c0','track_name').collect()

# %%
cancion_id_dict = {fila['_c0']: fila['track_name'] for fila in filas}

# %%
cancion_id_dict
# Out:
# {'539': 'Someone Like You',
#  '831': 'My Babe',
#  '1087': 'Makoti',
#  '1090': 'Triunfo - Live',
#  '1096': 'Black Organ',
#  '1109': 'Bienvenidos A Mi Mundo',
#  '1283': 'Feitiço',
#  '1793': 'Electro Movimiento',
#  '1974': 'Tropical Garden',
#  '2260': "Can't Stop",
#  '2363': 'Looking For Somebody (To Love)',
#  '2514': 'Happy Pills',
#  '2638': 'Presión',
#  '2783': 'Halloween',
#  '2989': 'De Paso Nomás',
#  '3050': 'Little Dark Age',
#  '3307': 'I Like Him',
#  '3723': 'Lithium',
#  '4817': 'The Narrow Path',
#  '4925': 'Walk With Us - For Black Lives Matter',
#  '4947': 'Tha',
#  '5020': "il vento d'oro",
#  '5240': 'Every Breath You Take',
#  '5339': 'The Reluctant Heroes',
#  '5880': 'Unholy God',
#  '6363': 'Left Hand March',
#  '6440': 'One With the Forest',
#  '6473': 'Köld',
#  '6697': 'Your War',
#  '6851': 'Dronning Ellisiv',
#  '6940': 'Puritania - Live',
#  '7127': 'Moon Over Memphis',
#  '7743': '100 Degrees in the Shade',
#  '8048': 'Sweet Home Alabama',
#  '8126': "I've Got My Love To Keep Me Warm",
#  '8134': 'Rudolph The Red-Nosed Reindeer',
#  '8442': 'I Wanna Be Your Dog',
#  '8578': 'Lay Down Sally',
#  '8584': 'After Midnight',
#  '8641': "That Bitch Ain't Me",
#  '9318': 'O Processo',
#  '9485': 'Quando o sol se for',
#  '10280': 'Signs',
#  '10561': 'Calabass',
#  '10653': 'Little Fling - Original Mix',
#  '10959': 'Mind Control',
#  '11558': 'Under',
#  '11579': 'Train Song',
#  '11794': 'Road',
#  '11814': "Daddy's Little Girl",
#  '12137': 'QUEEN - Live',
#  '12143': '月半小夜曲',
#  '12163': '執迷不悔',
#  '12418': '愛情disabled - Live',
#  '12505': '公司裁員三百人',
#  '12617': '驗孕的下晝 - Live',
#  '12620': '一步一生',
#  '12719': '冰箱',
#  '12874': "春夏秋冬 A Balloon's Journey",
#  '13170': 'Na Na Na (I Walks With God) [Mike Dunn Main Vocal Mixx]',
#  '13251': 'U Are - Aaron Smith Big Bass Mix',
#  '13335': "Huggin' & A Luvin' - Chocolate Puma Remix",
#  '13337': 'On & On - Vocal Album Mix',
#  '13363': "100% of Dissin You - Armando's Dis Mix",
#  '13495': 'Melodies from Heaven',
#  '13537': 'Mushrooms (Justin Martin Remix)',
#  '13606': 'Show U Love - DJ Deep Edit',
#  '13843': 'I Try',
#  '14074': "Lullaby & Goodnight (Brahm's Lullaby, Op. 49)",
#  '14108': 'Pat a Cake',
#  '14352': "Let's Get Ready!",
#  '14518': 'Down At the Station Early in the Morning',
#  '14715': 'My Friend Peppa',
#  '14851': 'Deck the Halls',
#  '14869': 'Where Is Thumbkin?',
#  '15051': 'moonlight',
#  '15246': 'Black Cherry',
#  '15422': 'I met you at the station',
#  '15782': "IF I DON'T TEXT YOU FIRST",
#  '15884': 'Good Night',
#  '15969': 'Would You Be My Baby',
#  '16153': 'When I Fall In Love',
#  '16266': 'Carnaval, Op. 9: No. 7, Coquette (Live in Japan, 2022)',
#  '16615': 'Slokam',
#  '16767': 'La clemenza di Tito, K.621 / Act 1: Marcia - Reprise',
#  '16900': 'Mozart: Piano Concerto No. 20 in D Minor, K. 466: III. Allegro assai',
#  '17010': 'LED Spirals - Extended Version',
#  '17249': 'onde',
#  '17541': 'Without You',
#  '17565': 'Stained Materials - Edit',
#  '17858': 'Jericho',
#  '17886': 'Silicone',
#  '18472': 'Chola Starter Kit',
#  '18662': 'The Grabbing Hand',
#  '19154': 'Jingle Bell Rock',
#  '19263': 'Feliz Navidad',
#  '19321': 'Sweet Home Alabama',
#  '19447': 'Santa Looked a Lot Like Daddy',
#  '19464': 'Natural',
#  '19493': 'What Child Is This?',
#  '19591': "Holdin' Her",
#  '20219': 'Monster',
#  '20719': 'Spicy',
#  '21140': 'Crocodile Teeth',
#  '21194': 'Owo Mi Da',
#  '21384': 'Boom Shack-A-Lak',
#  '21406': 'Jaiye Foreign',
#  '21544': 'Make Sense',
#  '21656': 'Pree Me',
#  '21765': 'Bank Alert',
#  '21770': 'Fever',
#  '21878': 'Book Smart',
#  '21884': 'Your Matter',
#  '21970': 'Trick',
#  '22256': 'Bed Of Razors',
#  '22391': 'Given in Death',
#  '22670': 'Sweet Relief',
#  '22997': 'Mission: Impossible',
#  '23054': 'Disconnected',
#  '23169': 'Weak',
#  '23256': 'Drew Barrymore',
#  '23388': 'Superpowers - Dimitri Vegas Edit',
#  '23783': "I'm The One - Tyron Hapi Remix",
#  '23990': 'Waikiki - Original Mix',
#  '24228': "The Groove That Won't Stop - Extended Remix",
#  '24776': 'Drive (I-75)',
#  '24792': 'DJ-KiCKS Track - (At Les)',
#  '24986': 'Do You Love What You Feel 2018 - Inner City & House Of Virus Extended Instrumental Mix',
#  '25048': 'Hot Stuff - Single Version',
#  '25176': 'I Feel You Everywhere (Antibodies)',
#  '25422': 'Let Me Make Love To You',
#  '26191': 'Des fissures apparaissent',
#  '26375': 'Trettifyran',
#  '26404': 'Opening Race',
#  '26426': 'Simon Smith and the Amazing Dancing Bear - 2002 Remaster',
#  '26563': 'Romeo and Juliet',
#  '27116': 'Sincerely Yours',
#  '27276': 'Makes Me',
#  '27468': 'Ignition',
#  '27702': 'Taken Away',
#  '27746': 'Revolution In Dub - DJ Madd Remix',
#  '27816': 'A Thousand Times',
#  '27963': 'Follow Me - Blanke Remix',
#  '28388': 'Monster',
#  '28733': 'Cool Down The Pace',
#  '28784': 'Closer I Get to You',
#  '28837': 'Out My Mind',
#  '28931': 'Something Beautiful (Tritonia 400)',
#  '29197': 'Closer Than You',
#  '30100': 'I Took A Pill In Ibiza - Seeb Remix',
#  '30314': 'Breaking Me',
#  '30429': 'All That Really Matters',
#  '30600': 'When I Grow Up (feat. Wiz Khalifa)',
#  '30720': 'OK Not To Be OK - Lost Stories Remix',
#  '30835': 'Stay Young',
#  '31142': 'Sexy Movimiento',
#  '31173': 'Hate Me',
#  '31214': '成长',
#  '31522': 'die first',
#  '31878': 'Faded - Lost Stories Remix',
#  '32097': 'Teardrop',
#  '32132': 'Give It To Me',
#  '32605': 'Intezaar',
#  '32632': 'Pump This',
#  '32651': 'I Need A Forest Fire',
#  '32823': 'Butterfly Effect',
#  '32902': 'Kaolo Pt.2 - Angger Dimas Remix',
#  '33014': 'Look At Me!',
#  '33034': "Sugar, We're Goin Down",
#  '33045': 'Misery Business',
#  '33792': 'Supersonic',
#  '33900': 'Зависай',
#  '33945': 'A Esperança Não Morreu',
#  '34023': 'Joy of Little Things',
#  '34487': 'Amuleto',
#  '34565': 'Ekka Raja Rani',
#  '34862': 'Cold Shoulders',
#  '34888': 'Christmas In April',
#  '35011': 'Basta Você Me Ligar - Ao Vivo',
#  '35150': 'Chupadinha',
#  '35469': 'Um Dia',
#  '35743': 'És Meu Bem Maior - Ao Vivo',
#  '36177': 'In My Mind',
#  '36183': 'Stay Yours',
#  '36192': 'La cage',
#  '36332': 'Point Final',
#  '36803': 'Superlove',
#  '36849': 'A Banda (Zwei Apfelsinen im Haar)',
#  '37350': 'Do For Love',
#  '37991': 'Presents for Christmas',
#  '38067': 'Selfless',
#  '38304': 'Beach Bummer',
#  '38585': 'Amor Verde',
#  '38624': 'Out of Jail',
#  '38709': "Please Don't Slow Me Down",
#  '38805': 'Plastic Tramp',
#  '39175': "Daddy's Eyes",
#  '39270': 'Hunting Grounds',
#  '39578': 'immer nur du',
#  '39707': 'All We Got (feat. KIDDO) - Ofenbach Remix',
#  '40022': 'Jeová Jireh',
#  '40179': 'Ele Não Mudou',
#  '40231': 'Nenhuma condenação há',
#  '40780': 'Ainda Estás Aqui',
#  '40987': 'De Joelhos',
#  '41278': 'Dark of the Day',
#  '41305': 'My Twin',
#  '41447': 'I Was a Teenage Frankenstein',
#  '41459': 'Empty Inside',
#  '41624': 'Soligt',
#  '12495': '"喜愛便一起 - 劇集 ""一笑渡凡間"" 主題曲"',
#  '17615': 'Alone',
#  '26952': 'True Sisters',
#  '35500': 'Convite - Ao Vivo',
#  '36760': 'Ride',
#  '41040': 'River en vacker dröm',
#  '42042': 'Apology for Praxeology',
#  '42136': 'External',
#  '42182': 'Next on the List',
#  '42635': 'Abolition',
#  '42890': 'Devoured Alive',
#  '42951': '... And By Best I Mean Worst',
#  '42963': 'Muteness',
#  '43316': 'What It Feels Like',
#  '43449': 'Serás Sempre Deus',
#  '43755': 'Back To Summer',
#  '43805': 'Ba Da Bam',
#  '43820': 'Halo - Vocal Mix',
#  '44001': 'In the End',
#  '44236': 'All My Life',
#  '44458': 'Dig',
#  '44633': 'Inside Out',
#  '44645': 'Hail, Hail - Live at ARCO Arena, Sacramento, CA - July 1998',
#  '44711': 'Here Without You',
#  '44977': 'Pensar Bien',
#  '45045': '"Raiders March (From ""Raiders of the Lost Ark"") [Live]"',
#  '45302': 'Black Star',
#  '45321': 'Ulili E',
#  '45414': 'Fields of Gold',
#  '45423': 'Haleakala Ku Hanohano',
#  '45507': 'Mirage',
#  '45577': 'Hasta Que Te Conoci',
#  '45686': 'Hawaiian Soul',
#  '45887': 'La Pomeña',
#  '46014': 'Slave to the Rave',
#  '46509': 'Speak My Mind - Original Mix',
#  '46729': 'Fuck Forever',
#  '46910': "We Like Marihuana - DJ Paul's Forze Mix",
#  '47236': 'Hoje - Ao Vivo',
#  '47506': 'Beco Sem Saída',
#  '47797': 'Charlie Brown Jr.',
#  '48091': 'Das Boot',
#  '48152': "X Gon' Give It To Ya",
#  '48962': 'Speed',
#  '49028': 'Psycho Style - Edit',
#  '49062': 'We Like to Party - Original Mix',
#  '49337': 'Move My Body - Deluzion Remix',
#  '49694': 'Locked Up',
#  '49720': 'Rebel To The Grave - Radio Edit',
#  '49849': 'Scrap Attack (Defqon.1 Anthem 2009) - Endymion Remix',
#  '50182': 'Debes Saberlo',
#  '50301': 'Штиль',
#  '50303': 'Vamos!!!',
#  '50374': 'Guitarrera',
#  '50421': 'Koe murha',
#  '50586': 'The Deadite Girls Gone Wild',
#  '50765': 'Beast in Black',
#  '50780': 'Salí a buscar',
#  '50787': 'Donde Está Mi Corazón - En Vivo',
#  '51315': 'Sajna, Say Yes To The Dress',
#  '51681': 'HOTEL LOBBY (Unc & Phew)',
#  '51878': 'For My Hand',
#  '52067': 'Jesus Remembered Me',
#  '52500': 'I Washed My Hands in Muddy Water',
#  '52804': 'Cowtown',
#  '52874': "I Don't Care (If Tomorrow Never Comes)",
#  '52973': "Don't Do It Darling",
#  '53119': 'Remember',
#  '53374': 'Everything but You',
#  '53940': 'Heavy Metal Love',
#  '54264': 'A Midsummer Nice Dream',
#  '54470': 'Monomom - Live',
#  '54635': 'Beneath Fleeting Visions',
#  '54780': 'さようなら',
#  '54823': 'Stop Parching Yourself',
#  '55248': 'Dil Pe Zakham Khate Hain',
#  '55265': '"For Aisha (Featured in ""The Sky Is Pink"")"',
#  '55382': 'Daayre - Lofi Flip',
#  '55417': 'Nanchaku',
#  '55483': 'Jiyein Kyun - Bollywood Lo-Fi;Chill;Remix',
#  '55697': 'Dhadak Dhadak',
#  '55723': 'Ekla Ghor',
#  '55820': 'Jode Rehjo Raaj',
#  '56074': 'Easy Lover',
#  '56179': 'Pause',
#  '56180': 'Chitthi Bhitra',
#  '56326': 'wonder if she loves me',
#  '56388': 'Hataarindai, Bataasindai',
#  '56410': 'Makeba',
#  '56530': 'Backyard Boy',
#  '56604': 'Courtside',
#  '56800': 'Mile High (feat. Travis Scott & Metro Boomin)',
#  '56835': 'Crying over You',
#  '56952': 'Crossfire',
#  '57295': 'What Christmas Means To Me - Single Version / Mono',
#  '57296': "Uptight (Everything's Alright) - Single Version",
#  '57870': 'Vadivelu on Acid',
#  '58012': 'Sweet Dreams (Are Made Of This)',
#  '58299': 'Wollt ihr das Bett in Flammen sehen',
#  '58353': 'Punk Weight',
#  '58418': 'Me & My Gun',
#  '58456': 'I Got You',
#  '58576': 'Testimonial',
#  '58620': 'god bless',
#  '58800': 'Quiet Now',
#  '58802': 'Soulfly XI',
#  '59181': 'Delusions of Omniscience',
#  '59302': 'The Path',
#  '59523': 'Inelegant',
#  '60161': 'Feel Like',
#  '60431': 'Rage',
#  '60803': 'Stay So',
#  '60804': 'Long Road',
#  '61036': '僕のヒロイン',
#  '61076': 'カレイドスコープ',
#  '61121': 'One Night Carnival',
#  '61505': 'だいじょばない',
#  '61539': 'オーケストラ <KASHiWACK version>',
#  '61828': '永遠より続くように(OKL48)',
#  '61995': 'らびゅ',
#  '62116': 'たぶん',
#  '62180': 'Touch off',
#  '62255': 'Rain',
#  '62552': 'Red Swan - TV Edit -',
#  '63612': 'August',
#  '63840': '噂',
#  '63871': 'Neon',
#  '64142': 'Rudolph The Red-Nosed Reindeer',
#  '64223': 'Have Yourself A Merry Little Christmas',
#  '64250': 'Nach Baliye',
#  '64478': 'Rudolph The Red-Nosed Reindeer',
#  '64499': 'It Might As Well Be Spring - Live At Carnegie Hall, NY / 1964',
#  '64713': 'Only Love Can Hurt Like This',
#  '64731': 'Zerdaliler',
#  '64943': 'The Christmas Song (Chestnuts Roasting on an Open Fire)',
#  '64954': 'Habits',
#  '65706': 'Into the I-LAND',
#  '65819': 'Dil Mera Tod Diya',
#  '65885': 'Moon',
#  '65988': 'Palakkattu Pakkathile',
#  '66176': 'Do The Robot Walk',
#  '66216': 'Head Shoulders Knees and Toes',
#  '66221': 'Pancakes for Dinner',
#  '66230': 'Boots The Monkey!',
#  '66324': 'A Man That Can Dance',
#  '66481': 'Hasta Mañana - Until Tomorrow',
#  '66638': 'Electric Slide',
#  '66752': 'Hide and Go Seek',
#  '67152': '1, 2, 3 (feat. Jason Derulo & De La Ghetto)',
#  '67603': 'Moscow Mule',
#  '67760': 'Pantysito',
#  '67978': 'Ojos De Video Tape',
#  '68090': 'Morado',
#  '68405': 'LENTITO',
#  '68840': '¡Qué Suerte, Qué Risa!',
#  '69130': 'Kaantha Reprised',
#  '69201': 'No Hook',
#  '69548': 'Yang Kutahu Cinta Itu Indah',
#  '69562': 'Enne Anbodu',
#  '69699': '"Mel Nattu Isai (From ""Jodi"")"',
#  '69833': 'Good Morning',
#  '70012': '愛人錯過',
#  '70101': '說好的幸福呢',
#  '70333': '光陰獨白 (電視劇《你是我的榮耀》片尾曲)',
#  '70414': '鬼',
#  '70563': '緣分一道橋',
#  '70666': '牡丹江',
#  '70719': '過火',
#  '71075': 'Planet Zero',
#  '71344': 'Arise',
#  '72013': 'Can You Feel My Heart - Remix',
#  '72103': 'Losing You',
#  '72219': 'Noise',
#  '72289': "Tears Don't Fall",
#  '72345': 'Bay of Pigs',
#  '72590': 'All Before',
#  '73042': 'Lymn - Extended Mix',
#  '73185': 'Sleepless - Stephan Bodzin Remix',
#  '73416': 'Mind Dimension - Kölsch Remix',
#  '73839': 'Shine - Original Mix',
#  '73930': 'Get It Right - Claude VonStroke Remix',
#  '73932': 'Spreading Plague - Perc Remix',
#  '74462': 'Rosa Flor - Ao Vivo',
#  '74515': 'O TEMPO É SUA MORADA :: celebrar',
#  '74517': 'Rosa Flor - Acústica',
#  '74833': 'Vai Ficar Na Saudade',
#  '74997': 'Sete Desejos - Ao Vivo',
#  '75444': 'Floodplain',
#  '75541': 'The Stone (Close Up)',
#  '75956': '"Theme from Schindler\'s List (Reprise) (from ""Schindler\'s List"")"',
#  '76295': '"La bohème, SC 67 / Act 3: ""Marcello. Finalmente!"""',
#  '76354': 'The Greatest Gift',
#  '76521': 'Leonora',
#  '76666': 'Menuets I & II',
#  '77095': 'Rodovia - Ao Vivo',
#  '77164': 'Vai e Chora - Ao Vivo',
#  '77343': 'Antes e depois (Participação especial de Dilsinho) - Ao vivo',
#  '77376': 'Pimpolho',
#  '77747': 'Tá Louco Héin / Eu Mereço Ser Feliz / Pura Adrenalina - Ao Vivo',
#  '77835': 'A Carta / Pra Mim Não É / Supera - Ao Vivo',
#  '78097': 'Abenteuerland',
#  '78183': "Jetzt geht's los - Jahrmarkt-Mix",
#  '78250': 'Layla - English Version',
#  '78313': 'Ihr könnt mich alle alle alle',
#  '78351': 'Chicken Dance',
#  '78580': 'Hobelbank',
#  '79785': 'A Thousand Years',
#  '79854': "Obito's Theme (Naruto Shippuden Original Soundtrack)",
#  '80059': 'Jaan Ban Gaye',
#  '80316': 'Ae Mere Humsafar',
#  '80387': 'Lae Dooba',
#  '80415': 'Bole Chudiyan',
#  '80490': 'Pala Pala',
#  '80629': '"Odhani (From ""Made in China"")"',
#  '80800': 'Tere Bin',
#  '81133': 'SPACESHIP',
#  '81283': 'Mistletoe',
#  '81420': 'Ek Tarfa',
#  '81522': '"Ra Ra Rakkamma (From ""Vikrant Rona"")"',
#  '81562': 'Life Goes On',
#  '81666': '"Thodi Jagah (From ""Marjaavaan"")"',
#  '81732': 'Jab Koi Baat - Recreated',
#  '81784': 'Maine Payal Hai Chhankai',
#  '81958': 'Cradles',
#  '82308': 'Rainbow Shiner',
#  '82369': "Let's Go",
#  '82479': 'Watch Me Fold',
#  '82732': 'Living In The Real World',
#  '82794': 'Your Hands (Together)',
#  '82909': 'Demons Are Real',
#  '82948': 'Red Red Wine - 2008 Remaster',
#  '83015': 'FRIENDS',
#  '83046': 'Antidote - Radio Edit',
#  '83074': 'Heaven Takes You Home (feat. Connie Constance)',
#  '83278': 'Human Touch',
#  '83369': 'Pjanoo - Radio Edit',
#  '83541': 'Assassin',
#  '83644': 'Praise (feat. Gunna)',
#  '84420': 'Ölüm',
#  '84761': 'Part III',
#  '84920': "It's Only Love - Remastered 2009",
#  '85151': 'Seven Nation Army - The Glitch Mob Remix',
#  '85361': 'Define',
#  '85770': 'Beynim Yok',
#  '86017': 'Ghost On The Dance Floor',
#  '86245': 'Daft Punk Is Playing at My House',
#  '86517': 'Nuotatori Professionisti',
#  '86951': 'Icky Thump',
#  '86993': 'Juegos Incompletos',
#  '87325': 'Un Muchacho Pobre',
#  '87329': 'Después de Tí No Hay Nada',
#  '87551': 'Paz Interior',
#  '87558': 'Lua E Estrela',
#  '87720': 'Guerra e Paz',
#  '88160': 'GATÚBELA',
#  '88257': 'CÓMO SE SIENTE - Remix',
#  '88324': 'Amor Pasajero',
#  '88899': 'Fuori Dal Tunnel',
#  '89071': 'La Rebelión',
#  '89080': 'No Es Justo',
#  '89146': 'Ahora Me Llama',
#  '89563': 'Perreo y Dembow',
#  '89738': 'Verano En París - Remix',
#  '89930': 'Perros y Gatas',
#  '89937': 'Toy Con la Bendición',
#  '90142': 'Dancing In The Street - Stereo',
#  '90504': 'Twilight Time - Single Version',
#  '90730': 'De Qué Manera Te Olvido',
#  '90742': 'El mar - Remastered',
#  '91457': 'Don’t Give Up On Me',
#  '91639': 'God Only Knows - Mono / 1997 Remastered',
#  '92088': 'Rocking Around the Christmas Tree',
#  '92266': "Don't Be Cruel",
#  '92374': "黒く塗りつぶせ - Live at 日本武道館'98 - Remastered 2022",
#  '92824': 'Like It That Way',
#  '92841': 'Summer Holiday - 2003 Remaster',
#  '93191': 'Тонкая рябина',
#  '93332': 'Хотел бы в единое слово',
#  '93411': 'Шарманщик',
#  '93458': 'Соловушка',
#  '93509': 'Две гитары',
#  '93699': 'Shestoj vagon vtoroe mesto',
#  '93759': 'Любушка',
#  '94057': 'savior',
#  '94079': 'Cup of Coffee',
#  '94397': 'Hasty',
#  '94833': 'am I not enough for you',
#  '95068': 'Lo Mío Es Amor',
#  '95115': 'Amandote',
#  '95531': 'Sueño Contigo',
#  '95562': 'Lloré Lloré',
#  '95794': 'Son de los Viejitos',
#  '96079': 'Primeiro Beijo - Ao Vivo',
#  '96137': 'No compasso do criador',
#  '96487': 'A Festa Do Santo Reis',
#  '97374': 'Cicatrizes - Ao Vivo',
#  '97687': 'Tá Faltando Amor - Ao Vivo Em Goiânia / 2007',
#  '97714': 'Vai Aprender Amar',
#  '97759': 'O Doutor e a Paixão',
#  '98489': 'Uns´re Kaiserin soll sich wiegen',
#  '98882': 'Love and the Weather',
#  '98982': '"Why We Build the Wall (""Behind closed doors..."") [Outro]"',
#  '99155': 'Khush to Hai Na',
#  '99335': 'The Werewolf',
#  '99374': 'Please Forgive Me',
#  '99402': 'Baria Dao',
#  '99489': 'American Pie',
#  '99873': 'Why You No Love Me',
#  '100090': 'A Vos',
#  '100350': 'Кукла колдуна',
#  '100408': 'Herencia',
#  '100740': 'Cigarettes & Whiskey',
#  '100900': 'Give a Little Bit',
#  '101082': 'Brown Noise For Sleep 9',
#  '101197': 'And the Glory of the Lord Shall Be Revealed (Remastered 2014)',
#  '101483': 'Pure Brown Noise with Pouring Rain',
#  '101898': 'White Noise - BP 940 hz',
#  '102025': 'Har Ek Pal',
#  '102038': 'Raaz Tera Mera',
#  '102340': 'Christmas All Over Again',
#  '102436': 'Tujhse Mehka',
#  '102637': 'Wasteland, Baby!',
#  '102761': 'Usne Kaha Tha',
#  '103081': 'What Christmas Means To Me - Single Version / Mono',
#  '103144': 'What Christmas Means To Me - Single Version / Mono',
#  '103171': "I Can't Help But Feel",
#  '103212': 'Nothing Feels Better',
#  '103624': 'Bittersweet',
#  '103706': 'Passion',
#  '103723': 'I Love You More than You’ll Ever Know',
#  '103797': 'Who Took The Merry Out Of Christmas',
#  '103837': 'The Christmas Waltz',
#  '103842': "Don't Forget To Feed The Reindeer",
#  '103901': 'Time Moves Slow',
#  '103978': 'Love Never Felt So Good',
#  '104014': 'Santería',
#  '104252': 'Cicatrices',
#  '104373': 'La Verdad',
#  '104383': 'Superhéroe',
#  '104437': 'Amor Sin Odio',
#  '104757': 'Moi et mes toi',
#  '104758': 'Ahora Lloras Tú (feat. CNCO)',
#  '105146': 'Blue Birds',
#  '105420': 'scuba dive bar',
#  '105553': 'Brooklyn Cowboy',
#  '106082': 'Broken',
#  '106160': 'Everything',
#  '106218': 'If I Ruled The World',
#  '106589': 'Kan man gifta sig i jeans?',
#  '106642': 'Stannar om du ber mig',
#  '106646': 'Till landet Ingenstans',
#  '106956': 'London',
#  '107193': 'Never Ending Story',
#  '107206': 'Курточка',
#  '107371': 'Enfance 80',
#  '107807': 'My Enemy',
#  '107922': "Un jour ou l'autre - Live 2019",
#  '108049': 'Que Nadie Sepa Mi Sufrir',
#  '108098': 'Fueron Tres Años',
#  '108309': 'CB Vals',
#  '108470': 'El Ciruja - En Vivo',
#  '108483': 'Volver',
#  '108701': 'Mentiras',
#  '109056': 'Cosmovision',
#  '109513': 'Boavista - Innellea Remix',
#  '109765': 'Fjäll',
#  '109792': 'Center to Center',
#  '109966': 'Dragon of Eden - Original Mix',
#  '110102': 'Red Lights',
#  '110338': 'Vikings - VIP Mix',
#  '111072': 'Tides',
#  '111233': 'Sunshine',
#  '111234': 'Insomnia - Monster Mix',
#  '111246': 'Another Bridge - 2012 Remaster',
#  '111592': 'Drifting Away',
#  '112131': 'Yemyeşil Bir Deniz',
#  '112270': 'Baksana Talihe',
#  '112353': 'Kadın',
#  '112849': 'Sardunyalar Arasında',
#  '112883': 'Feriğim',
#  '112961': 'Bu Aşk Beni Yorar',
#  '113191': 'Every Breath - Studio',
#  '113316': 'Elohim',
#  '113352': 'In The Name Of Love - Recorded At Spotify Studios NYC',
#  '113632': 'Sound Mind - Live',
#  '113714': 'Honesty',
#  '113866': 'This Year for Christmas',
#  '113887': 'Throne Room',
#  '51': '透明だった世界',
#  '134': 'You and I Both',
#  '234': 'Hold You in My Arms',
#  '350': 'Mirrors - Acoustic',
#  '388': '接吻',
#  '865': "Can't Go Back",
#  '1019': 'Demorô',
#  '1184': 'Jah Jah Revolta',
#  '1273': 'Una canción me trajo hasta aquí',
#  '1686': 'Baie de Sangareya',
#  '1792': 'Yo No Se',
#  '1836': 'When The Going Is Smooth & Good',
#  '1865': 'Tender Trap',
#  '1897': 'Bienvenida',
#  '1944': 'Ska Fuentes',
#  '1957': "There's a New Day Coming",
#  '2022': 'Mr. Brightside',
#  '2046': "Don't Shoot Me Santa",
#  '2076': 'Feel Invincible',
#  '2158': 'Heads Will Roll - A-Trak Remix',
#  '2490': 'La Soledad',
#  '2936': 'Es Poderoso',
#  '3026': 'When You Were Young',
#  '3304': 'Afraid',
#  '3862': 'A Little Piece of Heaven',
#  '4059': 'Touch',
#  '4516': 'Forever Distant',
#  '4723': 'Lido',
#  '4774': 'The Blood',
#  '4918': 'Today and it’s gone (Munich Session)',
#  '5260': "My War but is it okay if it's lofi?",
#  '5714': '我武者羅',
#  '5716': 'Dragon Slayer',
#  '5920': 'Love (Gaara Rap) [feat. Cg5]',
#  '5993': 'Epitafio',
#  '6469': 'Pełen czerni',
#  '6639': 'Diastric Alchemy',
#  '6954': 'Valdogg',
#  '7255': 'Centuries',
#  '7829': 'Nine Days',
#  '7946': 'Ruination Day Part 2',
#  '8021': 'Sleigh Ride',
#  '8108': 'The Secret Of Christmas',
#  '8260': 'All Along the Watchtower',
#  '8314': 'Born To Be Wild',
#  '8386': 'Presents for Christmas',
#  '8545': 'Cauchemar de course',
#  '8809': 'Sweet Home Alabama - Edit',
#  '9211': 'Tudo é Possível - Ao Vivo',
#  '9402': 'De Mais Ninguém',
#  '9773': 'pânico de nada',
#  '9963': 'O Tempo Passou',
#  '10103': 'Invaders Must Die',
#  '10220': 'Bushpig',
#  '10289': 'Let It Go (feat. Sporty-O) - Original Mix',
#  '10290': 'Bangerz (feat. Baby Anne)',
#  '10737': 'Right Now',
#  '10926': 'More',
#  '11529': 'Within You Without You - Remastered 2009',
#  '11628': "Don't Feel Like Feeling Sad Today",
#  '11732': 'Mountain To Move',
#  '12129': '我可以被這個世界淘汰,但不可以被世界擊敗',
#  '12183': '心淡',
#  '13011': 'Just a Kiss - Horacio & Aaron Smith Remix',
#  '13575': 'Take Me Up',
#  '14075': 'Mary Had a Little Lamb',
#  '14241': 'Jingle Bells',
#  '14298': "The Chipmunk Song (Christmas Don't Be Late) - Remastered 1999",
#  '14671': 'Baa Baa Black Sheep',
#  '14741': 'Three Rivers Hotel',
#  '15200': 'Know me',
#  '15203': 'My Favourite Clothes',
#  '15304': 'Crush On You',
#  '15413': 'Alive',
#  '15861': 'Late Night',
#  '15932': 'Snow & Sand',
#  '16050': 'Experience',
#  '16197': 'The Nutcracker, Op. 71, TH 14 / Act 1: No. 2 March - Live at Walt Disney Concert Hall, Los Angeles / 2013',
#  '16271': 'Lyric Pieces I, Op. 12 (Excerpts): No. 6, Norsk',
#  '16400': "Merry-Go-Round of Life - from 'Howl's Moving Castle'",
#  '16540': 'Jezus Malusieńki (Reworked by Hania Rani & Dobrawa Czocher)',
#  '16690': '12 Variations on ‘Je suis Lindor’ from ‘Le Barbier de Séville’ by A.L. Baudron in E, K.354: 12. Variation XI',
#  '16704': '"Piano Concerto No. 26 in D Major, K. 537 ""Coronation"": II. (Larghetto)"',
#  '16916': 'Sonata for Piano and Violin in E flat, K.481: 3f. Variation 5',
#  '16941': '8 Variations on ‘Come un agnello’ by Sarti in A, K.460: 1.Theme',
#  '17402': 'Platia',
#  '17556': 'Kiss of Jvdas - Original Mix',
#  '18448': '"Gump (Parody of ""Lump"" by The Presidents of the United States)"',
#  '18463': 'Echo',
#  '18554': 'Tingling',
#  '18866': 'Relationships',
#  '19059': 'You',
#  '19550': 'Where We Started',
#  '19713': 'Forever After All',
#  '19836': "Queens Don't",
#  '22038': 'Atur Aku',
#  '22439': 'Into Moshpit',
#  '22933': 'Circling the Drain',
#  '23080': 'Hypnotized',
#  '23089': 'Superman',
#  '23241': 'Let Me Take You',
#  '23470': 'Palmtree',
#  '23983': 'Rich & Famous (with Isac Elliot)',
#  '24089': "You Silk Suit Wearin Mulafuk'ka",
#  '24616': 'Omokase',
#  '25196': 'Simply Irresistible',
#  '25300': 'Gimme Gimme - Club Mix',
#  '25359': 'Karma Chameleon',
#  '25488': "While I'm Alone - Remastered",
#  '25574': 'All Night Long (All Night)',
#  '25618': 'Angel Eyes',
#  '25666': 'Olivia',
#  '25768': 'Attitudes',
#  '25843': 'Du bist alles auf dieser Welt',
#  '25934': "I've Seen That Face Before (Libertango)",
#  '25991': 'Pożegnanie',
#  '26456': '"Kiss the Girl - From ""The Little Mermaid""/ Soundtrack Version"',
#  '26481': '"A New Collar/Jock & Trusty/It\'s Jim Dear - From ""Lady and the Tramp""/Score"',
#  '26578': 'Life, Life',
#  '26596': 'Wieża Bruna',
#  '26832': '"A Dream Is a Wish Your Heart Makes (from ""Cinderella"")"',
#  '26854': 'The Games',
#  '27182': 'Killa',
#  '27352': 'Radiate',
#  '27513': 'Still Life',
#  '27763': 'Lost For Words',
#  '27820': 'I Got You (feat. Tyler Daley)',
#  '27965': 'Return Of Forever - Camo & Krooked & Mefjus Remix',
#  '28494': 'Até o Fim',
#  '28601': 'Divinity - ODESZA Remix',
#  '29272': 'Mirror',
#  '29831': 'Save My Grave',
#  '29976': 'Never Giving Up',
#  '30226': 'Heroes Tonight',
#  '30326': 'Lose Control',
#  '30545': 'Dive',
#  '30632': 'Loneliest Time Of Year',
#  '30644': "Don't You Wanna Play?",
#  '30802': 'Get Low',
#  '31137': 'Pegao',
#  '31155': 'So Good',
#  '31493': 'I Got A Feeling',
#  '31707': 'Till Forever Falls Apart',
#  '31839': 'False Alarm',
#  '31848': 'Blood In The Cut',
#  '31902': 'Love & War - Yellow Claw G-Funk Remix',
#  '32012': 'Mehmaan',
#  '32498': 'No Lo Digas',
#  '32859': 'Strobe',
#  '32873': 'Амфибия',
#  '33029': 'Teenagers',
#  '33158': 'Go Wild',
#  '33705': 'PAINLESS',
#  '34040': 'Thug Le',
#  '34304': 'Shiv Lingashtkam',
#  '35293': 'Cama Baguncada (feat. Japinha Conde & Conde do Forró)',
#  '35633': 'Filho Sem Sorte',
#  '35934': 'Raparigueiro da Roca',
#  '36158': 'Now or Never',
#  '36181': 'Hands Up - Single Version',
#  '36506': 'Brothers',
#  '36595': 'D.S.C.P',
#  '36832': 'Peut-être a-t-il rêvé?',
#  '36886': 'No Tube Zone',
#  '37055': 'Symphony (feat. Zara Larsson)',
#  '37226': 'Piloto da Nasa',
#  '37357': 'Favela Sinistra',
#  '37571': 'TROPA DA MAINSTREET SO TEM MALVADAO',
#  '37578': 'Vou Te Escrever Um Rap - Ao Vivo',
#  '37637': 'Vida de Rei',
#  '37969': 'Poesia de Sexta Feira',
#  '38136': 'SE15',
#  '38387': "Brin's Song",
#  '38639': 'White Lady Funerals',
#  '39001': 'The Middle',
#  '39407': 'Sun Will Shine',
#  '40008': 'Vou Deixar na Cruz',
#  '40074': 'Abraça-me / Lindo És / Só Quero Ver Você',
#  '40187': 'Ainda é Tempo (feat. Anderson Freire)',
#  '40431': 'Palavra Antiga',
#  '40441': 'Alfa E Ômega - Ao Vivo',
#  '40468': 'Esse Adorador',
#  '40476': 'Que Tal',
#  '40656': 'As Muitas Águas - Ao Vivo',
#  '40672': 'Esconderijo do Altíssimo',
#  '40950': 'Deus da Minha Vida',
#  '40979': 'Dependo de Ti',
#  '41102': 'Sleeping Sun',
#  '41678': 'Dear Prudence - Live At The Royal Albert Hall, London / 1983',
#  '13732': 'Take It Easy - Eli Escobar Remix',
#  '25478': 'Doskozzza',
#  '26195': 'Mirabel la tenace',
#  '28822': 'Walk Me Home - Blanke Remix',
#  '33372': "Tell the Reaper I'm Sorry",
#  '33720': 'Just One Yesterday',
#  '40974': 'Minha Menina',
#  '41734': "L'amour est bleu - Mellow Version",
#  '41817': 'Rob Pilatus',
#  '42249': 'Cloacula: The Anthropophagic Copromantik',
#  '42479': 'Raped in the Back of a Van',
#  '42527': 'Buried in the Crawlspace',
#  '42570': 'The Burning of the Deceased',
#  '42757': 'Insanity Dog',
#  '42918': 'Same Old Shit',
#  '43208': 'Pump the Brakes',
#  '43392': 'Meu Tributo',
#  '43478': 'Glória, Honra e Poder',
#  '43982': 'Primal Concrete Sledge',
#  '44091': 'Headful of Ghosts',
#  '44413': 'Lying from You',
#  '45181': "Romance D'Amour",
#  '45232': 'Pavane, Op. 50',
#  '45477': 'Rumination',
#  '45492': 'Make It Sweet (Instrumental Version)',
#  '45521': 'Un Vals',
#  '45535': 'Tha Pio Apopse To Feggari - Live',
#  '45602': 'The Air Between Us',
#  '45616': 'Lament in Tremelo Form',
#  '45734': "Jazz 'N' Samba (So Danco Samba)",
#  '45966': 'From Sounio to Sevilla',
#  '46477': 'Nessaja - Live / Tour 2006',
#  '46508': 'Toda Rhythm',
#  '46718': 'Dance More - DJ Edit',
#  '46719': 'I Come Correct - Ruthless Edit',
#  '47554': 'Rock You Like a Hurricane - 2011',
#  '47579': 'Insensível',
#  '47759': 'Just What I Needed',
#  '47969': '"Mighty Wings - From ""Top Gun"" Original Soundtrack"',
#  '48074': 'Survival of the Fittest',
#  '48295': 'Quieren Dinero',
#  '48431': 'Semoga Kau Sembuh, Pt. 2',
#  '48574': 'Laat Maar Waaien',
#  '49069': 'In The End - Dailucia Remix',
#  '49100': 'Formula 1 Theme - Hardstyle Version',
#  '49385': 'Guide You',
#  '49406': 'Forever Young (We Are)',
#  '49548': 'Betale!',
#  '49645': 'Promises',
#  '50205': 'Te Lo Vengo Diciendo',
#  '50406': 'Fome',
#  '50546': 'Los Ojos del Niño - Bonus Track',
#  '50596': 'Completamente Nervioso',
#  '50648': 'Ideando la Fuga',
#  '50730': 'Hacedor de Terror',
#  '50799': 'Vientos de Poder',
#  '50879': 'Conquistador',
#  '51194': 'Limbo',
#  '51528': 'ROCKSTAR',
#  '51538': 'Dua Lipa',
#  '51641': 'Calling My Spirit',
#  '52153': 'Bury Me Face Down',
#  '52165': "I'm Sorry For You My Friend",
#  '52335': 'We Must Have Been Out Of Our Minds',
#  '52413': 'New Mule Skinner Blues',
#  '52461': 'Move It On Over',
#  '52805': 'Whiskey Man',
#  '52909': 'Waiting for You',
#  '52977': "(We're Not) The Jet Set",
#  '53293': 'Kernkraft 400 (A Better Day)',
#  '53349': 'Feel Good',
#  '53514': 'Alone',
#  '53530': 'Love Me Like a Friend',
#  '53617': 'Desire - Gryffin Remix',
#  '54744': 'Sex Machine',
#  '55191': 'Do Pal',
#  '55256': 'Jay-Jaykara',
#  '55300': 'Main Kya Karoon',
#  '55609': 'Mere Nishaan',
#  '56055': 'So Good',
#  '56155': 'YKWIM?',
#  '56328': 'this is what falling out of love feels like',
#  '56351': 'Buniyaad',
#  '57132': 'Heat Waves',
#  '57496': "What They'll Say About Us",
#  '57577': 'Kenny',
#  '57824': 'Jeene Mein Aye Maza',
#  '58408': 'Walk On By',
#  '58518': 'Nutopia',
#  '59142': 'Opulent Night (For Mário de Sá-Carneiro)',
#  '59369': 'Mim',
#  '59660': 'The Road',
#  '59680': 'Setamkeshan',
#  '59777': 'Lost',
#  '59808': 'Life Story',
#  '60219': 'Pretty Like a Rose',
#  '60249': 'F***k Orgus (Dance) - Dr. Rude Remix',
#  '60416': 'Hold Me',
#  '60570': 'Givenchy',
#  '60898': 'First Class Flight (feat. Prince Swanny)',
#  '61528': '春はもうすぐ',
#  '61595': '世界の中心で虹を叫んだサマー',
#  '61663': '他の星から',
#  '61684': '届かなそうで届くもの',
#  '62044': "Christmas Don't Be Late",
#  '62104': 'ピースサイン',
#  '62111': 'Red Swan',
#  '62379': 'ただ声一つ',
#  '62611': '"Que Sera Sera (Whatever Will Be, Will Be) [From ""The Man Who Knew Too Much""] (with Frank DeVol & His Orchestra)"',
#  '63202': 'JUSTadICE',
#  '63213': '雪の音',
#  '63270': 'Eternal Flame',
#  '63506': 'もしも君が泣くならば',
#  '64164': 'Winter Wonderland',
#  '64331': 'Joy To The World - Remastered 1999',
#  '64535': 'Please Come Home For Christmas - Album Version / Addtl. Strings',
#  '64616': 'Happy Holiday',
#  '64988': 'Some Kind Of Wonderful',
#  '65163': 'Polaroid Love',
#  '65629': 'Edho Mogam',
#  '65860': 'I Love You Boy',
#  '65954': 'ASAP',
#  '66081': 'Bouncy Ball',
#  '66125': 'Dance Party in the House',
#  '66314': 'This Old Man',
#  '66479': 'Cada Semilla - Every Little Seed',
#  '66670': 'Cowboy Count',
#  '66983': 'With My Foot I Tap, Tap, Tap',
#  '67106': 'LA CANCIÓN',
#  '67233': 'Sexy Movimiento',
#  '67341': 'Danza Kuduro',
#  '67359': 'Tití Me Preguntó',
#  '67393': 'Te Quiero Más',
#  '67916': 'Voy Subiendo',
#  '68109': 'UN PESO',
#  '68236': 'Síguelo',
#  '68240': 'Imaginaste - Remix',
#  '68413': 'Taxi',
#  '68604': 'BABY OTAKU',
#  '68778': 'Porte',
#  '68790': 'Sonando Flaite - Remix',
#  '68900': 'Yo Voy',
#  '69012': 'I.O.Y.A (Ayyo Vayye)',
#  '69053': 'Neeyum Njanum',
#  '69301': 'Kanne - Namah',
#  '69657': 'Maa Jholiyan Bhardi',
#  '69829': 'Yeshu Manavalan',
#  '69901': 'Sultan',
#  '69959': 'Yamuna',
#  '70306': '會呼吸的痛',
#  '70956': '進階',
#  '70998': '除不盡的傷悲 - 電視劇《我是顧家男》片尾曲',
#  '71670': 'Closer',
#  '71732': 'Windowpane',
#  '71785': 'Valhalla Calling',
#  '72018': 'Avalanche',
#  '72475': 'Relapse',
#  '72560': 'Better Than You',
#  '72634': 'Alive',
#  '73149': "Gospel - Super Flu's Antichrist Remix",
#  '73331': 'Sunrise',
#  '73399': 'Check Yourself',
#  '73951': "What's That Called?",
#  '74027': "Neptune's Hep Tune",
#  '74066': 'Agridoce',
#  '74207': 'Puro Êxtase - Ao Vivo',
#  '74244': 'Retratos e Canções',
#  '74411': 'Ai Bebê',
#  '74465': 'Hoje Caminhei',
#  '74689': 'Tá Bom',
#  '74721': 'Vento No Litoral',
#  '74805': 'Drão',
#  '75218': 'To Take ...To Hold',
#  '75924': 'I',
#  '76022': "Attila - Mentre gonfiarsi l'anima",
#  '76214': 'Play Me',
#  '76252': 'Je T’aime',
#  '76670': 'Epiphany',
#  '76691': 'Zaïs: Overture - Live',
#  '76760': "'O Surdato 'nnamorato",
#  '76903': 'Forrest Gump Suite',
#  '76915': 'Now We Are Free',
#  '76969': "Finan's Isle Suite: Finan's Isle",
#  '77125': 'Onze e Pouquinho - Ao Vivo',
#  '77130': 'Fato Consumado / Quem Muito Quer Nada Tem - Ao Vivo',
#  '77329': 'Nunca Foi Sorte, Sempre Foi Deus - Ao Vivo',
#  '77490': 'Vai e Chora - Ao Vivo',
#  '78014': 'Hey Baby - Remastered 2019',
#  '78270': 'Ruinen und Beton',
#  '78470': 'Tote Enten (Xtreme Sound Party Mix)',
#  '78606': 'Hitmedley',
#  '78780': 'Lass uns schmutzig Liebe machen',
#  '79119': 'If I Lose Myself',
#  '79172': 'I Lived',
#  '79274': 'Over My Head (Cable Car)',
#  '79496': 'Esquece e Vem',
#  '79545': 'Something About The Way You Look Tonight - Edit Version',
#  '79588': 'DNA',
#  '79626': 'Qingyun Peak (Mellow)',
#  '79889': 'Pluvius',
#  '80038': '"Iktara (From ""Wake Up Sid"")"',
#  '80157': 'O Sanam',
#  '80333': '"Khamoshiyan (From ""Khamoshiyan"")"',
#  '80336': 'Bewajah',
#  '80445': 'Hothon Se Chhu Lo Tum - From Prem Geet',
#  '80883': 'Evare Nuvvu',
#  '81016': 'Peaches',
#  '81100': 'Calm Down (with Selena Gomez)',
#  '81199': 'Mera Dil Bhi Kitna Pagal Hai - Recreated Version',
#  '81296': 'Santa Claus Is Coming To Town',
#  '81908': 'Phir Mohabbat',
#  '81930': 'Tere Bin Nahi Laage (Male Version)',
#  '82325': 'Slow Motion',
#  ...}

# %%
df.columns
# Out:
# ['_c0',
#  'track_name',
#  'popularity',
#  'duration_ms',
#  'explicit',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'time_signature',
#  'track_genre']

# %%
df.show(2)
# Out:
# +---+----------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# |_c0|      track_name|popularity|duration_ms|explicit|danceability|energy|key|loudness|mode|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|time_signature|track_genre|
# +---+----------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# |539|Someone Like You|        57|     276146|       0|       0.439| 0.207|  1|  -9.573|   1|     0.0297|       0.608|             0.0|   0.186|  0.264|136.514|             4|   acoustic|
# |831|         My Babe|        59|     162040|       0|       0.676| 0.334|  5| -10.572|   1|     0.0508|       0.862|             0.0|    0.32|  0.867|  158.0|             4|   acoustic|
# +---+----------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+
# only showing top 2 rows

# %%
df = df.withColumn('duration_ms', col('duration_ms').cast('int')) \
    .filter(col('duration_ms').isNotNull())

# %%
df = df.withColumn('key', col('key').cast('int')) \
    .filter(col('key').isNotNull())

# %%
df = df.withColumn('mode', col('mode').cast('int')) \
    .filter(col('mode').isNotNull())

# %%
df = df.withColumn('time_signature', col('time_signature').cast('int')) \
    .filter(col('time_signature').isNotNull())

# %%
df = df.withColumn('danceability', col('danceability').cast('float')) \
    .filter(col('danceability').isNotNull())

# %%
df = df.withColumn('energy', col('energy').cast('float')) \
    .filter(col('energy').isNotNull())

# %%
df = df.withColumn('loudness', col('loudness').cast('float')) \
    .filter(col('loudness').isNotNull())

# %%
df = df.withColumn('speechiness', col('speechiness').cast('float')) \
    .filter(col('speechiness').isNotNull())

# %%
df = df.withColumn('acousticness', col('acousticness').cast('float')) \
    .filter(col('acousticness').isNotNull())

# %%
df = df.withColumn('instrumentalness', col('instrumentalness').cast('float')) \
    .filter(col('instrumentalness').isNotNull())

# %%
df = df.withColumn('liveness', col('liveness').cast('float')) \
    .filter(col('liveness').isNotNull())

# %%
df = df.withColumn('valence', col('valence').cast('float')) \
    .filter(col('valence').isNotNull())

# %%
df = df.withColumn('tempo', col('tempo').cast('float')) \
    .filter(col('tempo').isNotNull())

# %%
df = df.withColumn('_c0', col('_c0').cast('int')) \
    .filter(col('_c0').isNotNull())

# %%
df.dtypes
# Out:
# [('_c0', 'int'),
#  ('track_name', 'string'),
#  ('popularity', 'int'),
#  ('duration_ms', 'int'),
#  ('explicit', 'int'),
#  ('danceability', 'float'),
#  ('energy', 'float'),
#  ('key', 'int'),
#  ('loudness', 'float'),
#  ('mode', 'int'),
#  ('speechiness', 'float'),
#  ('acousticness', 'float'),
#  ('instrumentalness', 'float'),
#  ('liveness', 'float'),
#  ('valence', 'float'),
#  ('tempo', 'float'),
#  ('time_signature', 'int'),
#  ('track_genre', 'string')]

# %%
from pyspark.ml.feature import StringIndexer
indexer = StringIndexer(inputCol='track_genre', outputCol='class_numeric')
indexer_model = indexer.fit(df)
df_indexed = indexer_model.transform(df)

df_indexed.show()
# Out:
# +----+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+-------------+
# | _c0|          track_name|popularity|duration_ms|explicit|danceability|energy|key|loudness|mode|speechiness|acousticness|instrumentalness|liveness|valence|  tempo|time_signature|track_genre|class_numeric|
# +----+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+-------------+
# | 539|    Someone Like You|        57|     276146|       0|       0.439| 0.207|  1|  -9.573|   1|     0.0297|       0.608|             0.0|   0.186|  0.264|136.514|             4|   acoustic|         97.0|
# | 831|             My Babe|        59|     162040|       0|       0.676| 0.334|  5| -10.572|   1|     0.0508|       0.862|             0.0|    0.32|  0.867|  158.0|             4|   acoustic|         97.0|
# |1087|              Makoti|         0|     274933|       0|       0.469| 0.824|  8| -10.785|   1|     0.0944|       0.478|           0.268|   0.076|  0.781|220.081|             4|   afrobeat|          0.0|
# |1090|      Triunfo - Live|        34|     273426|       0|        0.54| 0.945|  1|  -5.021|   1|      0.271|       0.315|             0.0|   0.405|  0.551| 92.013|             4|   afrobeat|          0.0|
# |1096|         Black Organ|        34|     191506|       0|       0.837| 0.598|  1|  -9.047|   0|      0.181|       0.391|           0.238|  0.0598|  0.983|145.219|             4|   afrobeat|          0.0|
# |1109|Bienvenidos A Mi ...|        33|     237026|       1|       0.658| 0.715| 10|  -7.416|   0|      0.269|      0.0174|             0.0|   0.307|  0.543|189.895|             4|   afrobeat|          0.0|
# |1283|             Feitiço|        24|     262425|       0|       0.869| 0.797|  6|  -4.455|   1|     0.0318|       0.414|             0.0|  0.0852|  0.973|121.996|             4|   afrobeat|          0.0|
# |1793|  Electro Movimiento|        19|     196986|       0|       0.803|  0.86|  8|  -6.522|   1|      0.135|      0.0782|         4.45E-5|   0.128|  0.534|109.966|             4|   afrobeat|          0.0|
# |1974|     Tropical Garden|        16|     502693|       0|       0.615| 0.397|  0| -17.526|   0|     0.0859|       0.301|           0.886|  0.0277|  0.916|  169.0|             4|   afrobeat|          0.0|
# |2260|          Can't Stop|        82|     269000|       0|       0.618| 0.938|  9|  -3.442|   1|     0.0456|      0.0179|             0.0|   0.167|  0.875| 91.455|             4|   alt-rock|          1.0|
# |2363|Looking For Someb...|        72|     178617|       1|       0.522| 0.957|  2|  -4.924|   1|     0.0687|      0.0515|          0.0014|   0.144|  0.917| 170.91|             4|   alt-rock|          1.0|
# |2514|         Happy Pills|        71|     203080|       0|       0.521| 0.885|  4|  -4.934|   0|      0.125|     0.00327|         0.00904|   0.324|  0.344|115.985|             4|   alt-rock|          1.0|
# |2638|             Presión|        47|     238346|       0|       0.414| 0.938| 10|  -4.592|   0|     0.0684|      0.0602|         1.18E-6|    0.11|  0.643| 99.014|             4|   alt-rock|          1.0|
# |2783|           Halloween|         0|     221466|       0|       0.223|  0.91|  7|  -7.097|   1|       0.08|      0.0116|         5.18E-4|   0.212|  0.364| 171.75|             4|   alt-rock|          1.0|
# |2989|       De Paso Nomás|        44|     185501|       0|       0.646| 0.846|  7|  -4.427|   1|     0.0282|      0.0584|             0.0|   0.376|  0.965|126.022|             4|   alt-rock|          1.0|
# |3050|     Little Dark Age|        83|     299960|       0|       0.705| 0.712|  6|  -6.156|   1|     0.0385|      0.0102|         8.55E-4|     0.1|   0.62| 97.512|             4|alternative|          2.0|
# |3307|          I Like Him|        66|     132453|       1|       0.893| 0.579|  9|  -8.995|   1|      0.113|      0.0641|         1.21E-4|   0.215|  0.611|133.018|             4|alternative|          2.0|
# |3723|             Lithium|        73|     257053|       0|       0.678| 0.656|  7|   -6.41|   1|     0.0381|     0.00174|             0.0|  0.0631|  0.485|123.207|             4|alternative|          2.0|
# |4817|     The Narrow Path|        39|     226857|       0|       0.167|0.0709|  5| -25.474|   1|     0.0341|       0.967|           0.958|   0.107| 0.0391|111.917|             4|    ambient|          3.0|
# |4925|Walk With Us - Fo...|        57|     120456|       0|       0.299|0.0264|  9| -26.535|   0|     0.0469|       0.995|           0.882|   0.073|  0.235|168.963|             5|    ambient|          3.0|
# +----+--------------------+----------+-----------+--------+------------+------+---+--------+----+-----------+------------+----------------+--------+-------+-------+--------------+-----------+-------------+
# only showing top 20 rows

# %%
df_indexed.columns
# Out:
# ['_c0',
#  'track_name',
#  'popularity',
#  'duration_ms',
#  'explicit',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'time_signature',
#  'track_genre',
#  'class_numeric']

# %%
import pandas as pd

# %%
df_pandas = pd.DataFrame(df_indexed.collect())

# %%
df_pandas
# Out:
#             0                                                  1   2       3   \
# 0          539                                   Someone Like You  57  276146
# 1          831                                            My Babe  59  162040
# 2         1087                                             Makoti   0  274933
# 3         1090                                     Triunfo - Live  34  273426
# 4         1096                                        Black Organ  34  191506
# ...        ...                                                ...  ..     ...
# 113860  112862                                             Gringo  38  213514
# 113861  113058                                       The Blessing  60  423193
# 113862  113432            Estudiar Con Sonidos de Truenos, Pt. 03  28   97581
# 113863  113599  Meditación Budista (Musica de Relajacion para ...  25  396033
# 113864  113768                                   Niebla Hirviendo  23  116000
#
#         4       5      6   7          8   9       10       11        12  \
# 0        0  0.4390  0.207   1  -9.573000   1  0.0297  0.60800  0.000000
# 1        0  0.6760  0.334   5 -10.572000   1  0.0508  0.86200  0.000000
# 2        0  0.4690  0.824   8 -10.785000   1  0.0944  0.47800  0.268000
# 3        0  0.5400  0.945   1  -5.021000   1  0.2710  0.31500  0.000000
# 4        0  0.8370  0.598   1  -9.047000   0  0.1810  0.39100  0.238000
# ...     ..     ...    ...  ..        ...  ..     ...      ...       ...
# 113860   1  0.7190  0.634  10  -6.393000   0  0.0958  0.06600  0.000025
# 113861   0  0.3670  0.463  11  -7.638000   1  0.0335  0.12100  0.000010
# 113862   0  0.1610  0.897  10 -22.398001   0  0.0804  0.00163  0.920000
# 113863   0  0.0748  0.202   1 -16.792999   1  0.0368  0.98700  0.939000
# 113864   0  0.2490  0.995   1 -21.726000   1  0.0722  0.17800  0.819000
#
#             13       14          15  16           17    18
# 0       0.1860  0.26400  136.514008   4     acoustic  97.0
# 1       0.3200  0.86700  158.000000   4     acoustic  97.0
# 2       0.0760  0.78100  220.080994   4     afrobeat   0.0
# 3       0.4050  0.55100   92.013000   4     afrobeat   0.0
# 4       0.0598  0.98300  145.218994   4     afrobeat   0.0
# ...        ...      ...         ...  ..          ...   ...
# 113860  0.0918  0.37800  149.934006   4      turkish  95.0
# 113861  0.0983  0.18700  139.996002   4  world-music  96.0
# 113862  0.8630  0.02470  110.366997   4  world-music  96.0
# 113863  0.1240  0.03400   66.177002   4  world-music  96.0
# 113864  0.3970  0.00984  110.245003   4  world-music  96.0
#
# [113865 rows x 19 columns]

# %%
df_pandas.to_csv("C:/Dropbox/CursoSpark/pandas_spotify.csv")
